# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../src/')
from dice_roller import *

d = Dice_Roller('3d6 + 5')

fig, ax = plt.subplots()
ax.plot(d.value.outcomes(), d.value.probabilities())
ax.set_xlabel('value')
ax.set_ylabel('probability')
fig.savefig('../assets/images/example-distribution.png')
plt.show()
